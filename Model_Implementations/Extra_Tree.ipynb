# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import recall_score,accuracy_score,confusion_matrix,precision_score,f1_score,roc_curve,auc,multilabel_confusion_matrix
import pandas as pd
import optuna
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train=pd.read_csv(r"D:\ML Project\Data Splits\X_train.csv")
X_val=pd.read_csv(r"D:\ML Project\Data Splits\X_val.csv")
X_test=pd.read_csv(r"D:\ML Project\Data Splits\X_test.csv")

Y_train=pd.read_csv(r"D:\ML Project\Data Splits\Y_train.csv")['class']
Y_val=pd.read_csv(r"D:\ML Project\Data Splits\Y_val.csv")['class']
Y_test=pd.read_csv(r"D:\ML Project\Data Splits\Y_test.csv")['class']

# %%
# n_estimators=list(range(50,350,50))
# criterion=['gini','entropy']
# max_depth=list(range(3,11))
# max_features=['sqrt','log2']
# min_samples_leaf=list(range(1,6,1))
# min_samples_split=list(range(2,11,1))
# bootstrap=[True,False]

# %%
def objective(trial):
    n_estimators=trial.suggest_int('n_estimators',50,300)
    criterion=trial.suggest_categorical('criterion',['gini','entropy'])
    max_depth=trial.suggest_int('max_depth',3,10)
    max_features=trial.suggest_categorical('max_features',['sqrt','log2'])
    min_samples_leaf=trial.suggest_int('min_samples_leaf',1,5)
    min_samples_split=trial.suggest_int('min_samples_split',2,10)
    bootstrap=trial.suggest_categorical('bootstrap',[True,False]) 

    model=ExtraTreesClassifier(n_estimators=n_estimators,max_depth=max_depth,max_features=max_features,min_samples_leaf=min_samples_leaf,min_samples_split=min_samples_split,bootstrap=bootstrap,criterion=criterion,random_state=50)
    model.fit(X_train,Y_train)
    Y_val_pred=model.predict(X_val)
    accuracy_val=accuracy_score(Y_val,Y_val_pred)

    return accuracy_val


study=optuna.create_study(direction='maximize')
study.optimize(objective,n_trials=50)

# direction='maximize' since we are working on acuracy which needs to be maximized
# Out:
# [I 2026-05-25 12:41:55,217] A new study created in memory with name: no-name-b290d885-aa59-4900-a124-32f99e1d6f03
# [I 2026-05-25 12:41:57,431] Trial 0 finished with value: 0.8029 and parameters: {'n_estimators': 97, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'bootstrap': False}. Best is trial 0 with value: 0.8029.
# [I 2026-05-25 12:42:00,187] Trial 1 finished with value: 0.9477 and parameters: {'n_estimators': 72, 'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 1 with value: 0.9477.
# [I 2026-05-25 12:42:07,706] Trial 2 finished with value: 0.9377 and parameters: {'n_estimators': 241, 'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 1 with value: 0.9477.
# [I 2026-05-25 12:42:17,481] Trial 3 finished with value: 0.9692 and parameters: {'n_estimators': 264, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 3 with value: 0.9692.
# [I 2026-05-25 12:42:21,564] Trial 4 finished with value: 0.7392 and parameters: {'n_estimators': 255, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 3 with value: 0.9692.
# [I 2026-05-25 12:42:22,689] Trial 5 finished with value: 0.7703 and parameters: {'n_estimators': 58, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'bootstrap': False}. Best is trial 3 with value: 0.9692.
# [I 2026-05-25 12:42:32,103] Trial 6 finished with value: 0.9392 and parameters: {'n_estimators': 255, 'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 3 with value: 0.9692.
# [I 2026-05-25 12:42:36,600] Trial 7 finished with value: 0.8358 and parameters: {'n_estimators': 141, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 3 with value: 0.9692.
# [I 2026-05-25 12:42:43,564] Trial 8 finished with value: 0.9707 and parameters: {'n_estimators': 124, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 8 with value: 0.9707.
# [I 2026-05-25 12:42:49,368] Trial 9 finished with value: 0.9728 and parameters: {'n_estimators': 91, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'bootstrap': True}. Best is trial 9 with value: 0.9728.
# [I 2026-05-25 12:43:01,158] Trial 10 finished with value: 0.9688 and parameters: {'n_estimators': 187, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'bootstrap': False}. Best is trial 9 with value: 0.9728.
# [I 2026-05-25 12:43:10,085] Trial 11 finished with value: 0.9739 and parameters: {'n_estimators': 130, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 11 with value: 0.9739.
# [I 2026-05-25 12:43:23,267] Trial 12 finished with value: 0.9751 and parameters: {'n_estimators': 179, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 12 with value: 0.9751.
# [I 2026-05-25 12:43:35,625] Trial 13 finished with value: 0.9764 and parameters: {'n_estimators': 193, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 13 with value: 0.9764.
# [I 2026-05-25 12:43:47,339] Trial 14 finished with value: 0.9716 and parameters: {'n_estimators': 191, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 13 with value: 0.9764.
# [I 2026-05-25 12:43:58,242] Trial 15 finished with value: 0.977 and parameters: {'n_estimators': 220, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:44:07,879] Trial 16 finished with value: 0.9688 and parameters: {'n_estimators': 219, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:44:17,210] Trial 17 finished with value: 0.9332 and parameters: {'n_estimators': 213, 'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:44:33,724] Trial 18 finished with value: 0.9551 and parameters: {'n_estimators': 296, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:44:45,289] Trial 19 finished with value: 0.976 and parameters: {'n_estimators': 152, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:45:00,338] Trial 20 finished with value: 0.9736 and parameters: {'n_estimators': 216, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:45:12,346] Trial 21 finished with value: 0.976 and parameters: {'n_estimators': 153, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:45:24,127] Trial 22 finished with value: 0.9753 and parameters: {'n_estimators': 158, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:45:36,491] Trial 23 finished with value: 0.9718 and parameters: {'n_estimators': 200, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:45:46,288] Trial 24 finished with value: 0.9694 and parameters: {'n_estimators': 167, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:02,911] Trial 25 finished with value: 0.9759 and parameters: {'n_estimators': 235, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:17,643] Trial 26 finished with value: 0.9618 and parameters: {'n_estimators': 284, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 6, 'bootstrap': False}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:24,989] Trial 27 finished with value: 0.911 and parameters: {'n_estimators': 202, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:32,329] Trial 28 finished with value: 0.9742 and parameters: {'n_estimators': 108, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:41,949] Trial 29 finished with value: 0.9519 and parameters: {'n_estimators': 172, 'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 7, 'bootstrap': False}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:46:54,729] Trial 30 finished with value: 0.9687 and parameters: {'n_estimators': 234, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:04,815] Trial 31 finished with value: 0.9759 and parameters: {'n_estimators': 149, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:13,681] Trial 32 finished with value: 0.9718 and parameters: {'n_estimators': 158, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:19,942] Trial 33 finished with value: 0.974 and parameters: {'n_estimators': 111, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:26,822] Trial 34 finished with value: 0.9755 and parameters: {'n_estimators': 137, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:35,744] Trial 35 finished with value: 0.9718 and parameters: {'n_estimators': 184, 'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 15 with value: 0.977.
# [I 2026-05-25 12:47:41,434] Trial 36 finished with value: 0.9781 and parameters: {'n_estimators': 86, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:47:42,894] Trial 37 finished with value: 0.7384 and parameters: {'n_estimators': 81, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:47:45,571] Trial 38 finished with value: 0.972 and parameters: {'n_estimators': 54, 'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:47:55,335] Trial 39 finished with value: 0.943 and parameters: {'n_estimators': 246, 'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:00,343] Trial 40 finished with value: 0.9645 and parameters: {'n_estimators': 111, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:13,843] Trial 41 finished with value: 0.9757 and parameters: {'n_estimators': 226, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:18,077] Trial 42 finished with value: 0.976 and parameters: {'n_estimators': 67, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:30,514] Trial 43 finished with value: 0.9776 and parameters: {'n_estimators': 203, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:40,018] Trial 44 finished with value: 0.9727 and parameters: {'n_estimators': 204, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 10, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:50,282] Trial 45 finished with value: 0.9759 and parameters: {'n_estimators': 191, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 9, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:48:55,479] Trial 46 finished with value: 0.9715 and parameters: {'n_estimators': 97, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'bootstrap': False}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:49:07,452] Trial 47 finished with value: 0.9761 and parameters: {'n_estimators': 271, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:49:16,713] Trial 48 finished with value: 0.9671 and parameters: {'n_estimators': 266, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 7, 'bootstrap': True}. Best is trial 36 with value: 0.9781.
# [I 2026-05-25 12:49:25,889] Trial 49 finished with value: 0.9689 and parameters: {'n_estimators': 271, 'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 6, 'bootstrap': True}. Best is trial 36 with value: 0.9781.

# %%
optuna_ET = study.trials_dataframe()
optuna_ET.to_csv(r"D:\ML Project\Model_Tuned_Parameter_data\Optuna_ET.csv", index=False)

# %%
with open(r"D:\ML Project\Model_Tuned_Parameter_data\Parameters\ET.json", "w") as f:
    input=study.best_trial.params
    input['Accuracy']=study.best_trial.value
    json.dump(input, f)

# %%
print(f'Validation best accuracy: {study.best_trial.value}')
print(f'Validation best parameters: {study.best_trial.params}')
# Out:
# Validation best accuracy: 0.9781
# Validation best parameters: {'n_estimators': 86, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9, 'bootstrap': True}

# %%
with open(r"D:\ML Project\Model_Tuned_Parameter_data\Parameters\ET.json", "r") as f:
    loaded_dict = json.load(f)

params = dict(list(loaded_dict.items())[:-1])
validation_accuracy=loaded_dict['Accuracy']

# %%
model_best=ExtraTreesClassifier(**params,random_state=50)  # *8 unpacks the dictionary and allows us to pass the dictionary keys as keywords (parameter keywords) in the function

# Dictionary Unpacking in Function CallsThe ** operator allows you to take key-value pairs from a dictionary and pass them as named keyword arguments to a function. Experts on Stack Overflow explain that this enables dynamic argument handling.pythondef greet(name, age):
#     print(f"Hello {name}, you are {age} years old.")

# data = {"name": "Alice", "age": 25}
# greet(**data)  # Equivalent to greet(name="Alice", age=25)
# Use code with caution.3. Collecting Arguments (**kwargs)In a function definition, ** collects any number of keyword arguments into a single dictionary, typically named kwargs. A guide on Medium highlights how this provides a shortcut for accepting flexible inputs.pythondef show_info(**kwargs):
#     for key, value in kwargs.items():
#         print(f"{key}: {value}")

# show_info(city="New York", job="Developer") 
# # kwargs becomes {'city': 'New York', 'job': 'Developer'}
# Use code with caution.4. Merging Dictionaries (Python 3.5+)You can use ** inside a dictionary literal to merge multiple dictionaries into one.pythondict1 = {"a": 1}
# dict2 = {"b": 2}
# merged = {**dict1, **dict2}  # Output: {'a': 1, 'b': 2}


model_best.fit(X_train,Y_train)
# Out:
# ExtraTreesClassifier(bootstrap=True, criterion='entropy', max_depth=10,
#                      min_samples_leaf=4, min_samples_split=9, n_estimators=86,
#                      random_state=50)

# %%
Y_train_pred=model_best.predict(X_train)

Accuracy_train=accuracy_score(Y_train,Y_train_pred)

Accuracy_train       # Train Accuracy
# Out:
# 0.978125

# %% [markdown]
# ## Test Set Analysis ###########

# %%
Y_test_pred=model_best.predict(X_test)

# %%
Accuracy_test=accuracy_score(Y_test,Y_test_pred)
Accuracy_test                                 # Test Accuracy
# Out:
# 0.9767

# %%
conf_matrix=confusion_matrix(Y_test,Y_test_pred)


plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix,annot=True,cmap='Blues')

plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
### Recall

Macro_average_recall=recall_score(Y_test,Y_test_pred,average='macro')
Per_class_recall=recall_score(Y_test,Y_test_pred,average=None)

Macro_average_recall   ## Macro Recall and accuracy both are high. So class imbalance is not a problem
# Out:
# 0.9421093672425709

# %%
Per_class_recall    ## Class imbalance is not an issue as per recall since per class recall for all 3 classes is very high.
# Out:
# array([0.99151584, 0.84294235, 0.99186992])

# %%
## Precision

Macro_average_precision=precision_score(Y_test,Y_test_pred,average='macro')
Per_class_precision=precision_score(Y_test,Y_test_pred,average=None)

Macro_average_precision   ## Macro Average Precision is also very high
# Out:
# 0.9765801401857983

# %%
Per_class_precision  ## Even per class precision is also very high
# Out:
# array([0.98005963, 0.97808535, 0.97159543])

# %%
## F1 score

Macro_average_f1_score=f1_score(Y_test,Y_test_pred,average='macro')
Per_class_f1_score=f1_score(Y_test,Y_test_pred,average=None)

Macro_average_f1_score   ## Macro Average Precision is also very high
# Out:
# 0.9576272171386658

# %%
Per_class_f1_score
# Out:
# array([0.98575445, 0.9054992 , 0.981628  ])

# %%
## Sensitivity and Specificity

mcm = multilabel_confusion_matrix(Y_test,Y_test_pred)

tn = mcm[:, 0, 0]
fp = mcm[:, 0, 1]
fn = mcm[:, 1, 0]
tp = mcm[:, 1, 1]

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

sensitivity
# Out:
# array([0.99151584, 0.84294235, 0.99186992])

# %%
specificity
# Out:
# array([0.97721465, 0.99788748, 0.98304279])

# %%
Metrics={'Training Accuracy':Accuracy_train,'Validation Accuracy (Post Optuna Tuning)':validation_accuracy,'Test Accuracy':Accuracy_test,'Macro Average Recall':Macro_average_recall,
         'Per Class Recall':Per_class_recall,'Macro Average Precision':Macro_average_precision,'Per Class Precision':Per_class_precision,'Macro Average F1 Score':Macro_average_f1_score,
         'Per Class F1 Score':Per_class_f1_score,'Sensitivity':sensitivity,'Specificity':specificity}

Metrics=pd.Series(Metrics)

# %%
Metrics
# Out:
# Training Accuracy                                                                    0.978125
# Validation Accuracy (Post Optuna Tuning)                                               0.9781
# Test Accuracy                                                                          0.9767
# Macro Average Recall                                                                 0.942109
# Per Class Recall                            [0.9915158371040724, 0.8429423459244533, 0.991...
# Macro Average Precision                                                               0.97658
# Per Class Precision                         [0.9800596347372345, 0.9780853517877739, 0.971...
# Macro Average F1 Score                                                               0.957627
# Per Class F1 Score                          [0.9857544517338331, 0.9054991991457555, 0.981...
# Sensitivity                                 [0.9915158371040724, 0.8429423459244533, 0.991...
# Specificity                                 [0.9772146507666098, 0.9978874805425839, 0.983...
# dtype: object

# %%
Metrics.to_csv(r'D:\ML Project\Model_Metrics\Extra_Tree.csv',header=False)
